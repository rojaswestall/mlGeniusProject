# %%
import pandas as pd
data = pd.read_csv("/Users/hemuram/Desktop/EECS/mlGeniusProject/train.csv")
train = pd.read_csv("/Users/hemuram/Desktop/EECS/mlGeniusProject/train.csv")
test = pd.read_csv("/Users/hemuram/Desktop/EECS/mlGeniusProject/test.csv")

# %%
import seaborn as sns
#numerical outputs
train_numerical = train[['Accepted_Annotations','Annotation_Count','Comment_Count','Followers','Genius_IQ','Length_Referent_Text','Number_Contributors','Number_Verified_Annotations','Page_Views','Pyong_Count','Release_Date']]
train_numerical.head()
train_corr = train_numerical.corr()

# plot the heatmap and annotation on it
sns.heatmap(train_corr, xticklabels=train_corr.columns, yticklabels=train_corr.columns, annot=True)

# %%
import numpy as np
avg = np.mean(train['Total_Votes'])
train['Good?'] = np.where(train['Total_Votes']>=avg, '1', '0')

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
from sklearn.cross_validation import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train.head()
# Out:
#    Accepted_Annotations  Annotation_Count  Annotation_Is_Verified  \
# 0                    54                58                   False
# 1                    26                35                   False
# 2                    18                19                   False
# 3                    24                27                   False
# 4                    29                32                   False
#
#   Classification  Comment_Count  Featured_Video  Followers Genius_IQ    Hot  \
# 0       accepted              0           False        693         ?  False
# 1     unreviewed              0           False        598         ?  False
# 2       accepted              0           False       8610         ?  False
# 3       accepted              0           False        693         ?  False
# 4       accepted              0            True      17568    144243  False
#
#    Is_Description  ...    Length_Referent_Text  Meme_Verified  \
# ...

# %%
#splitting X and Y 
X = train.values[:,0:19]
Y = train.values[:,20]

# %%
clf_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100,
                               max_depth=3, min_samples_leaf=5)

# %%
def writet_to_csv(data):
    df = pandas.DataFrame(data)
    df.to_csv('./test.csv')

# %%
import pandas

writet_to_csv(train)
